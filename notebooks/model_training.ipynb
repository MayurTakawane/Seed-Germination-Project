# %%
import pandas as pd

# %%
df = pd.read_csv("data\modeldata.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Area      X     Y     XM    YM  Perimeter     BX    BY  Width  \
# 0           0  94.3  131.7  16.1  131.7  16.1       36.8  125.9  10.2   11.5
# 1           1  89.1  233.0  16.7  233.0  16.7       36.5  227.8  11.1   10.6
# 2           2  90.9  156.5  17.0  156.5  17.0       35.5  151.2  11.3   10.6
# 3           3  79.7  207.5  16.7  207.5  16.7       33.7  202.3  11.3   10.2
# 4           4  86.7   80.9  17.6   80.9  17.6       35.2   75.5  11.9   10.8
#
#    Height Result   Type
# 0    11.5     no     no
# 1    11.5     no     no
# 2    11.3     no     no
# 3    10.6    yes  small
# 4    10.8     no     no

# %%
df = df.drop(columns=['Unnamed: 0','Type'])

# %%
df.head()
# Out:
#    Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height  \
# 0  94.3  131.7  16.1  131.7  16.1       36.8  125.9  10.2   11.5    11.5
# 1  89.1  233.0  16.7  233.0  16.7       36.5  227.8  11.1   10.6    11.5
# 2  90.9  156.5  17.0  156.5  17.0       35.5  151.2  11.3   10.6    11.3
# 3  79.7  207.5  16.7  207.5  16.7       33.7  202.3  11.3   10.2    10.6
# 4  86.7   80.9  17.6   80.9  17.6       35.2   75.5  11.9   10.8    10.8
#
#   Result
# 0     no
# 1     no
# 2     no
# 3    yes
# 4     no

# %%
df['Result'].value_counts()
# Out:
# Result
# yes    421
# no      79
# Name: count, dtype: int64

# %%
df['Result'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['Result'] = df['Result'].replace('no','0')
df['Result'] = df['Result'].replace('yes','1')

# %%
df['Result'].unique()
# Out:
# array(['0', '1'], dtype=object)

# %%
df['Result'].value_counts()
# Out:
# Result
# 1    421
# 0     79
# Name: count, dtype: int64

# %%
## Independent and dependent features
X = df.drop(columns="Result",axis=1)
Y = df[["Result"]]

# %%
## Define which column should be ordinal encoded and which should be scaled
## Spliting X data
numerical_col = X.select_dtypes(exclude="object").columns

# %%
print(numerical_col)
# Out:
# Index(['Area', 'X', 'Y', 'XM', 'YM', 'Perimeter', 'BX', 'BY', 'Width',
#        'Height'],
#       dtype='object')

# %%
## using this library to automate the handling of missing value it will fill all missing value with (mean,median and mode)
from sklearn.impute import SimpleImputer

## using this library for feature scaling 
from sklearn.preprocessing import StandardScaler

## using this library for converting catgorical features into numerical features
## whenever our catorical features have rank we use OrdinalEncoder, else we use OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

## using library for pipeline, we need to perform simpleImputer then pass the result to StandartScaler then pass the result to Encoder
## pipeline just combines the step
## pipline is just connecting
from sklearn.pipeline import Pipeline

## now the connection is done we need to group this 
## for that we use library 
from sklearn.compose import ColumnTransformer

# %%
# Creating pipeline

# Numerical pipeline

num_pipeline = Pipeline(
    steps=[
        ('imputer',SimpleImputer(strategy='median')),
        ('scaler',StandardScaler())
    ]
)

# Now we have two pipelines lets combine it 
preprocessor = ColumnTransformer(
    [
    ('numPipeline',num_pipeline,numerical_col)
    ]
)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('numPipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['Area', 'X', 'Y', 'XM', 'YM', 'Perimeter', 'BX', 'BY', 'Width',
#        'Height'],
#       dtype='object'))])

# %%
# Train test split
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.30,random_state=30)

# %%
print(X_train,y_train,X_test,y_test)
# Out:
#       Area      X      Y     XM     YM  Perimeter     BX     BY  Width  Height
# 12    87.6  206.4   40.6  206.4   40.6       35.4  201.2   35.1   10.6    10.6
# 136  108.1  155.5   91.2  155.5   91.2       39.7  149.9   84.9   11.9    12.1
# 368   74.7  128.0   88.0  128.0   88.0       34.1  123.2   83.2   11.1     9.7
# 367   76.6  114.6   88.3  114.6   88.3       34.2  109.7   83.2   10.8     9.9
# 406   70.9  131.6   10.6  131.6   10.6       35.5  126.6    5.8   10.0    10.0
# ..     ...    ...    ...    ...    ...        ...    ...    ...    ...     ...
# 140  109.2  271.0  106.4  271.0  106.4       39.5  265.2  100.9   12.6    11.2
# 301   86.8   12.1    7.5   12.1    7.5       39.3    6.7    2.2   12.2    10.0
# 429   76.2  131.2   54.2  131.2   54.2       40.1  126.2   49.3    9.8    12.0
# 421   76.2  195.4   47.8  195.4   47.8       43.2  190.3   42.9   10.1    11.3
# 293   76.2  118.6  129.2   84.4  129.2       33.5   84.4  148.3   10.4    10.5
#
# [350 rows x 10 columns]     Result
# 12       0
# 136      1
# 368      1
# 367      1
# 406      1
# ..     ...
# 140      1
# 301      1
# 429      1
# 421      1
# 293      1
#
# [350 rows x 1 columns]       Area      X      Y     XM     YM  Perimeter     BX     BY  Width  Height
# 21    83.3  206.9   61.2  206.9   61.2       33.9  201.7   55.9   10.2    10.4
# 239   69.7  138.6   57.2  160.6   57.2       34.3   18.9   58.0   12.9    10.9
# 103  110.2  156.4   16.6  156.4   16.6       39.2  150.6   10.8   11.9    11.7
# 273   70.2   39.6  100.6  114.1  100.6       35.0  121.2  110.1   10.9     9.4
# 22    86.0  157.2   62.8  157.2   62.8       35.2  151.9   57.2   10.6    10.6
# ..     ...    ...    ...    ...    ...        ...    ...    ...    ...     ...
# 32    80.0  182.5   84.7  182.5   84.7       34.0  177.4   80.0   10.4    10.0
# 238   77.9   25.4   50.0   38.9   50.0       34.1   91.0   55.5    9.7     9.8
# 188   93.3   19.3  215.1   19.3  215.1       38.4   13.9  209.6   11.0    10.8
# 463   71.9  161.5  137.6  161.5  137.6       33.6  156.6  133.2    9.9     9.7
# 352   74.5   55.3   73.9   55.3   73.9       34.4   50.5   69.1   11.0     9.7
#
# [150 rows x 10 columns]     Result
# 21       1
# 239      1
# 103      1
# 273      1
# 22       0
# ..     ...
# 32       1
# 238      1
# 188      1
# 463      1
# 352      1
#
# [150 rows x 1 columns]

# %%
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
models={
    "random_forest":RandomForestClassifier(oob_score=True),
    "logistic_regression":LogisticRegression(),
    "decision_tree":DecisionTreeClassifier()
}

# %%
from sklearn.metrics import accuracy_score
def evaluate_model(X_train,y_train,X_test,y_test,models):
    report={}
    for i in range(len(models)):
        model=list(models.values())[i]
        model.fit(X_train,y_train)
        print(model.score(X_train,y_train))
        #print("OOB score:", model.oob_score_)
        
        y_pred=model.predict(X_test)
        
        accuracy=round(accuracy_score(y_test,y_pred)*100,2)
        
        report[list(models.keys())[i]]=accuracy
    
    return report

# %%
evaluate_model(X_train,y_train.values.ravel(),X_test,y_test,models)  ## using values ravel beacause it was giving warning for 1d array
# Out:
# 1.0
# 0.8342857142857143
# 1.0
# {'random_forest': 82.67, 'logistic_regression': 84.67, 'decision_tree': 74.0}

# %%
params={
    
    "n_estimators":[50,100,200],
    "criterion":["gini","entropy"],
    "max_depth":[3,5,10]
    
}

# %%
model=RandomForestClassifier(oob_score=True)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
cv=RandomizedSearchCV(model,param_distributions=params,scoring='accuracy',cv=5,verbose=3)

# %%
cv.fit(X_train,y_train.values.ravel())
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=50;, score=0.829 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=50;, score=0.843 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=50;, score=0.829 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=50;, score=0.829 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=50;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=100;, score=0.843 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=100;, score=0.843 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=100;, score=0.829 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=100;, score=0.843 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=100;, score=0.843 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=50;, score=0.814 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=50;, score=0.886 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=50;, score=0.829 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=50;, score=0.800 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=50;, score=0.814 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.829 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.843 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.829 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.843 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.843 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=200;, score=0.814 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=200;, score=0.843 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=200;, score=0.829 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=200;, score=0.814 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=200;, score=0.857 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=100;, score=0.814 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=100;, score=0.843 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=100;, score=0.843 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=100;, score=0.786 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=100;, score=0.871 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.814 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.843 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.829 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.814 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.829 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.800 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.843 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.843 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=100;, score=0.843 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=0.800 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=0.829 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=0.843 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=0.814 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=50;, score=0.814 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.829 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.843 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.829 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.857 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=200;, score=0.857 total time=   0.3s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(oob_score=True),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [3, 5, 10],
#                                         'n_estimators': [50, 100, 200]},
#                    scoring='accuracy', verbose=3)

# %%
cv.best_params_
# Out:
# {'n_estimators': 200, 'max_depth': 3, 'criterion': 'gini'}

# %%
bestmodel=RandomForestClassifier(n_estimators=50,max_depth=3,criterion='gini')

# %%
bestmodel.fit(X_train,y_train)
# Out:
# c:\Users\MAYUR\anaconda3\envs\SeedGermination\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(max_depth=3, n_estimators=50)

# %%
y_pred=bestmodel.predict(X_test)

# %%
best_accuracy=round(accuracy_score(y_test,y_pred)*100,2)

# %%
best_accuracy
# Out:
# 86.0
