# %% [markdown]
# # `Data Information`
#
# `Area`: The area of the object or shape.
#
# `X, Y`: Coordinates of the center of mass of the object.
#
# `XM, YM`: Coordinates of the centroid of the object.
#
# `Perimeter`: The perimeter or circumference of the object.
#
# `BX, BY`: Coordinates of the bounding box (or bounding rectangle) that encloses the object.
#
# `Width`, Height: Dimensions of the bounding box (width and height).
#
# `Result`: Possibly an outcome or a specific value related to the object.
#
# `Type`: Could represent the type or category of the object.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('data/ALL_FEATURES_CLEANED_DATA.xlsx')

# %%
data.head()
# Out:
#    Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height  \
# 0  94.3  131.7  16.1  131.7  16.1       36.8  125.9  10.2   11.5    11.5
# 1  89.1  233.0  16.7  233.0  16.7       36.5  227.8  11.1   10.6    11.5
# 2  90.9  156.5  17.0  156.5  17.0       35.5  151.2  11.3   10.6    11.3
# 3  79.7  207.5  16.7  207.5  16.7       33.7  202.3  11.3   10.2    10.6
# 4  86.7   80.9  17.6   80.9  17.6       35.2   75.5  11.9   10.8    10.8
#
#   Result   Type
# 0     no     no
# 1     no     no
# 2     no     no
# 3    yes  small
# 4     no     no

# %%
data.shape
# Out:
# (500, 12)

# %%
data[data['Result'] == 'yes'].shape
# Out:
# (421, 12)

# %%
data[data['Result'] == 'no'].shape
# Out:
# (79, 12)

# %%
yes = data[data['Result'] == 'yes']

# %%
no = data[data['Result'] == 'no']

# %%
plt.figure(figsize=[15,10])
yes.boxplot()
plt.show()

# %%
plt.figure(figsize=[15,10])
no.boxplot()
plt.show()

# %% [markdown]
# # Conclusion :
#
# ## yes ===>
# ```
# Seeds AREA near 75 has high probability to grow
# Coordinates of the center of mass, X near 100 and Y near 80 has high probability to grow
# Coordinates of the centroid, XM near 100 and YM near 85 has high probability to grow
# Perimeter, near 35 has high probability to grow
# Coordinates of the bounding box (or bounding rectangle) that encloses the object, BX near 95 and BY 80 has high probability to grow
# Width near 12 and height near 12 has high probability to grow
# ```
#
#
# ## N0 ===>
# ```
# Seeds AREA near 80-85 has high probability that they will not grow
# Coordinates of the center of mass, X near 110 and Y near 120 has high probability that they will not grow
# Coordinates of the centroid, XM near 110 and YM near 120 has high probability that they will not grow
# Perimeter, near 40 has high probability that they will not grow
# Coordinates of the bounding box (or bounding rectangle) that encloses the object, BX near 105 and BY 120 has high probability that they will not grow
# Width near 15 and height near 15 has high probability that they will not grow
# ```
