# %%
import pandas as pd
# Out:
# C:\Users\MAYUR\AppData\Local\Temp\ipykernel_24092\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('get_data/excelData/Results.csv')

# %%
data = data.drop(columns=' ')

# %%
len(data)
# Out:
# 100

# %%
data.drop(1)
# Out:
#        Area        X        Y       XM       YM  Perim.       BX       BY  \
# 0   100.155  198.316   24.585  198.316   24.585  38.109  192.727   19.091
# 2    89.463  175.127   25.124  175.127   25.124  36.934  169.773   19.545
# 3    92.407  120.617   25.343  120.617   25.343  36.580  115.455   19.773
# 4    93.750  139.987   25.540  139.987   25.540  40.548  133.864   20.000
# 5   103.874   82.848   26.296   82.848   26.296  40.437   77.045   20.455
# ..      ...      ...      ...      ...      ...     ...      ...      ...
# 95   89.411  196.778  209.765  196.778  209.765  36.213  190.455  204.545
# 96   92.097  159.103  210.054  159.103  210.054  38.220  153.182  204.773
# 97   81.560   63.904  210.149   63.904  210.149  35.006   58.409  205.000
# 98  104.545  138.993  211.659  138.993  211.659  38.619  132.727  205.682
# 99   93.543  119.261  211.828  119.261  211.828  36.392  114.091  206.364
#
#      Width  Height
# 0   10.909  11.364
# 2   10.682  10.909
# 3   10.455  11.364
# 4   11.364  11.136
# 5   11.136  11.818
# ..     ...     ...
# 95  11.591  10.455
# 96  11.364  10.455
# 97  10.455  10.455
# 98  11.818  11.818
# 99  10.227  10.909
#
# [99 rows x 10 columns]

# %%
area = []
x = []
y = []
xm = []
ym = []
perim = []
bx = []
by = []
width = []
height = []

# %%
i = 0
while(len(data) > 0):
    area.append(data['Area'][i])
    x.append(data['X'][i])
    y.append(data['Y'][i])
    xm.append(data['XM'][i])
    ym.append(data['YM'][i])
    perim.append(data['Perim.'][i])
    bx.append(data['BX'][i])
    by.append(data['BY'][i])
    width.append(data['Width'][i])
    height.append(data['Height'][i])
    data.drop([i],axis=0)
    i = i + 1
    if i == 100:
        break

# %%
print(len(area))
print(len(x))
print(len(y))
print(len(xm))
print(len(ym))
print(len(perim))
print(len(bx))
print(len(by))
print(len(width))
print(len(height))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
from src.pipeline.prediction_pipeline import predictPipeline,customData
import numpy as np

# %%
data=customData(
    Area = float(90),
    X = float(16),
    Y = float(455),
    XM = float(200),
    YM = float(100),
    Perimeter = float(30),
    BX = float(100),
    BY = float(100),
    Width = float(20),
    Height = float(20)
)
dataframe = data.convert_data_into_dataframe()
print(dataframe)
pred = predictPipeline()
results = pred.prediction(dataframe)
print(results)
# Out:
#    Area     X      Y     XM     YM  Perimeter     BX     BY  Width  Height
# 0  90.0  16.0  455.0  200.0  100.0       30.0  100.0  100.0   20.0    20.0
# ['yes']

# %%
i = 0
data=customData(
        Area = float(np.round(area[i])),
        X = float(np.round(x[i])),
        Y = float(np.round(y[i])),
        XM = float(np.round(xm[i])),
        YM = float(np.round(ym[i])),
        Perimeter = float(np.round(perim[i])),
        BX = float(np.round(bx[i])),
        BY = float(np.round(by[i])),
        Width = float(np.round(width[i])),
        Height = float(np.round(height[i]))
    )
dataframe = data.convert_data_into_dataframe()
print(dataframe)
pred = predictPipeline()
results = pred.prediction(dataframe)
# Out:
#     Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height
# 0  100.0  198.0  25.0  198.0  25.0       38.0  193.0  19.0   11.0    11.0

# %%
i = 0
while(i < 100):
    data=customData(    
        Area = float(np.round(area[i])),
        X = float(np.round(x[i])),
        Y = float(np.round(y[i])),
        XM = float(np.round(xm[i])),
        YM = float(np.round(ym[i])),
        Perimeter = float(np.round(perim[i])),
        BX = float(np.round(bx[i])),
        BY = float(np.round(by[i])),
        Width = float(np.round(width[i])),
        Height = float(np.round(height[i]))
    )
    dataframe = data.convert_data_into_dataframe()
    print(dataframe)
    pred = predictPipeline()
    results = pred.prediction(dataframe)
    if results == 'yes':
        print('Result ===> The Seed will Grow')
    else:
        print('Result ===> The Seed will not Grow')
    print(results)
    i = i + 1
# Out:
#     Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height
# 0  100.0  198.0  25.0  198.0  25.0       38.0  193.0  19.0   11.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height
# 0  91.0  159.0  25.0  159.0  25.0       36.0  154.0  20.0   10.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height
# 0  89.0  175.0  25.0  175.0  25.0       37.0  170.0  20.0   11.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height
# 0  92.0  121.0  25.0  121.0  25.0       37.0  115.0  20.0   10.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height
# 0  94.0  140.0  26.0  140.0  26.0       41.0  134.0  20.0   11.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#     Area     X     Y    XM    YM  Perimeter    BX    BY  Width  Height
# 0  104.0  83.0  26.0  83.0  26.0       40.0  77.0  20.0   11.0    12.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area      X     Y     XM    YM  Perimeter    BX    BY  Width  Height
# 0  97.0  103.0  26.0  103.0  26.0       38.0  98.0  21.0   11.0    12.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area     X     Y    XM    YM  Perimeter    BX    BY  Width  Height
# 0  99.0  62.0  27.0  62.0  27.0       40.0  55.0  21.0   12.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area     X     Y    XM    YM  Perimeter    BX    BY  Width  Height
# 0  98.0  43.0  27.0  43.0  27.0       41.0  38.0  22.0   11.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#     Area     X     Y    XM    YM  Perimeter    BX    BY  Width  Height
# 0  105.0  24.0  28.0  24.0  28.0       40.0  18.0  22.0   12.0    12.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#     Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height
# 0  103.0  198.0  46.0  198.0  46.0       38.0  192.0  40.0   12.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#     Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height
# 0  100.0  160.0  47.0  160.0  47.0       38.0  154.0  41.0   12.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#     Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height
# 0  100.0  142.0  47.0  142.0  47.0       39.0  137.0  41.0   11.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area     X     Y    XM    YM  Perimeter    BX    BY  Width  Height
# 0  99.0  84.0  47.0  84.0  47.0       38.0  78.0  42.0   11.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#     Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height
# 0  100.0  179.0  47.0  179.0  47.0       40.0  172.0  42.0   12.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height
# 0  85.0  122.0  47.0  122.0  47.0       35.0  116.0  42.0   11.0    10.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area     X     Y    XM    YM  Perimeter    BX    BY  Width  Height
# 0  99.0  63.0  48.0  63.0  48.0       38.0  57.0  42.0   11.0    12.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area      X     Y     XM    YM  Perimeter    BX    BY  Width  Height
# 0  92.0  102.0  48.0  102.0  48.0       36.0  96.0  42.0   11.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#     Area     X     Y    XM    YM  Perimeter    BX    BY  Width  Height
# 0  105.0  44.0  48.0  44.0  48.0       44.0  37.0  43.0   12.0    12.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area     X     Y    XM    YM  Perimeter    BX    BY  Width  Height
# 0  91.0  25.0  49.0  25.0  49.0       40.0  19.0  43.0   12.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#     Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height
# 0  106.0  122.0  66.0  122.0  66.0       39.0  115.0  61.0   12.0    12.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height
# 0  85.0  142.0  66.0  142.0  66.0       41.0  136.0  61.0   10.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#     Area      X     Y     XM    YM  Perimeter     BX    BY  Width  Height
# 0  106.0  160.0  67.0  160.0  67.0       40.0  153.0  61.0   12.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area     X     Y    XM    YM  Perimeter    BX    BY  Width  Height
# 0  99.0  82.0  67.0  82.0  67.0       38.0  76.0  61.0   11.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#    Area      X     Y     XM    YM  Perimeter    BX    BY  Width  Height
# 0  95.0  100.0  67.0  100.0  67.0       38.0  94.0  61.0   11.0    11.0
# holll
# Result ===> The Seed will Grow
# ['yes']
#     Area     X     Y    XM    YM  Perimeter    BX    BY  Width  Height
# 0